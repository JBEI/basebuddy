# %%
import pandas as pd
pd.read_csv('cocoput_table.tsv', sep='\t', index_col=False)[['Taxid', 'Species']].to_csv('cocoput_index.csv')

# %%
# !ls -lah
# Out:
# total 307856
# drwxr-xr-x   7 jacobroberts  staff   224B Feb 23 17:29 .
# drwxr-xr-x  15 jacobroberts  staff   480B Feb 23 17:24 ..
# drwxr-xr-x@  3 jacobroberts  staff    96B Feb 23 17:27 .ipynb_checkpoints
# -rw-r--r--@  1 jacobroberts  staff   4.9K Feb 23 17:29 Untitled.ipynb
# -rw-r--r--@  1 jacobroberts  staff   8.5M Feb 23 17:29 cocoput_index.csv
# -rw-r--r--@  1 jacobroberts  staff   101M Feb  9 14:41 cocoput_table.tsv
# -rw-r--r--   1 jacobroberts  staff    41M Feb  9 14:41 cocoput_table.tsv.tar.gz

# %%
# %%time
pd.read_csv('cocoput_table.tsv', sep='\t', index_col=False)
# Out:
# CPU times: user 1.43 s, sys: 341 ms, total: 1.77 s
# Wall time: 1.78 s
#        Division         Assembly    Taxid                      Species  \
# 0        refseq              NaN     1423            Bacillus subtilis
# 1        refseq              NaN   189381     Rossellomorea marisflavi
# 2        refseq              NaN   561879            Bacillus safensis
# 3        refseq              NaN     1408             Bacillus pumilus
# 4        refseq              NaN   155322          Bacillus toyonensis
# ...         ...              ...      ...                          ...
# 235200   refseq              NaN   345030  Groundnut yellow spot virus
# 235201   refseq              NaN  2053671      Escherichia phage FEC14
# 235202   refseq              NaN  2137745   Enterobacter phage EspM4VN
# 235203   refseq  GCF_900083295.1     1280        Staphylococcus aureus
# 235204   refseq              NaN    60456       Iris yellow spot virus
#
# ...

# %%
# %%time
pd.read_csv('cocoput_index.csv', index_col=False)
# Out:
# CPU times: user 109 ms, sys: 30.7 ms, total: 140 ms
# Wall time: 142 ms
#         Unnamed: 0    Taxid                      Species
# 0                0     1423            Bacillus subtilis
# 1                1   189381     Rossellomorea marisflavi
# 2                2   561879            Bacillus safensis
# 3                3     1408             Bacillus pumilus
# 4                4   155322          Bacillus toyonensis
# ...            ...      ...                          ...
# 235200      235200   345030  Groundnut yellow spot virus
# 235201      235201  2053671      Escherichia phage FEC14
# 235202      235202  2137745   Enterobacter phage EspM4VN
# 235203      235203     1280        Staphylococcus aureus
# 235204      235204    60456       Iris yellow spot virus
#
# [235205 rows x 3 columns]
